# %%
import numpy as np

# %%
#mean
age=[23,25,27,32,27]

# %%
np.mean(age)
# Out:
# np.float64(26.8)

# %%
np.median(age)
# Out:
# np.float64(27.0)

# %% [raw]
# numpy doesn't have mode function so we use scipy

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy import stats

# %%
no=[1,2,2,3,4,5,2,4,5]
stats.mode(no) #gives the mode and also the no of times it occurred
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(3))

# %%
#we can also use statistics module

# %%
pip install statistics
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/638.5 kB ? eta -:--:--
#    ---------------------------------------- 638.5/638.5 kB 5.1 MB/s  0:00:00
# ...
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7507 sha256=bdd0dbeda0f919efebbb17c626cd5ad4c5faea0fc65cf72f680f0331202053e3
#   Stored in directory: c:\users\bindhu_alia\appdata\local\pip\cache\wheels\81\6b\04\dd3cc29a5f3bdba002365cb7ddb8ac0e72272099f245740657
# Successfully built statistics
# ...
#
#    ---------------------------------------- 0/2 [docutils]
#    ---------------------------------------- 0/2 [docutils]
# ...

# %%
import statistics as st

# %%
st.mode(no)
# Out:
# 2

# %%
st.mean(no)
# Out:
# 3.111111111111111

# %%
st.median(no)
# Out:
# 3
