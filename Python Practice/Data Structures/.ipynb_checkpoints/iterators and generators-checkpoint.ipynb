# %%
#iterable is a python data structure that has the capability to return each of its member one at a time 
#examples include list,string ,tuple and not integer

# %% [raw]
# In the below example s is the iterable obj and i is iterator and the whole for loop process is iteration
# in the back end when we run the for loop python will a create a iterable object using iter and then access each ele using next till all elements are iterated

# %%
s='bindhu'
for i in s:
    print(i)
# Out:
# b
# i
# n
# d
# h
# u

# %% [raw]
# The below is the backend process of python loops

# %%
st=iter('bindhu')
next(st)
# Out:
# 'b'

# %%
next(st)
# Out:
# 'i'

# %%
next(st)
# Out:
# 'n'

# %%
next(st)
# Out:
# 'd'

# %%
next(st)
# Out:
# 'h'

# %%
next(st)
# Out:
# 'u'

# %%
next(st)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 next(st)
#
# StopIteration:

# %%
#generator function >> it just generates results one by one
def sq_gen(n):
    for i in range(n):
        yield i**2

# %%
d=sq_gen(6)
next(d)
# Out:
# 0

# %%
next(d)
# Out:
# 1

# %%
next(d)
# Out:
# 4
