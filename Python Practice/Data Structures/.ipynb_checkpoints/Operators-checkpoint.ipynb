# %%
# power operator is **
2**3
# Out:
# 8

# %%
#floor operator
4//3
# Out:
# 1

# %%
4/3
# Out:
# 1.3333333333333333

# %%
# logical operators are written as and / or
5 and 6
# Out:
# 6

# %%
not True
# Out:
# False

# %%
#member ship opereator in / not in
a="bakatarajit"
"b" in a
# Out:
# True

# %%
# identity operator - it checks whether two variables are pointing to the same memory location or not
a=2
b=4
a is b
# Out:
# False

# %%
a=3
b=a
a is b
# Out:
# True

# %%
# to get binary representation of any number 
bin(47)
# Out:
# '0b101111'

# %%
if 2>5:
    print('yes')
elif 4<2:
    print('no')
else:
    print('yop')
# Out:
# yop
