# %%
t=(2,'bindhu','tarajit', 4.5,'tarajit')
t
# Out:
# (2, 'bindhu', 'tarajit', 4.5, 'tarajit')

# %%
t[2]#tuples are immutable
# Out:
# 'tarajit'

# %%
t.count('tarajit')
# Out:
# 2

# %%
t.index('tarajit')#first occuring index
# Out:
# 2

# %%
t[::-1]
# Out:
# ('tarajit', 4.5, 'tarajit', 'bindhu', 2)

# %%
t1=(4,6,4,3,7)
t=t+t1
t
# Out:
# (2, 'bindhu', 'tarajit', 4.5, 'tarajit', 4, 6, 4, 3, 7, 4, 6, 4, 3, 7)

# %%
#sets doesnt allow any duplicate elements and indexing doesn't work here
s={2,3,5,5,5}
s
# Out:
# {2, 3, 5}

# %%
#to convert a set into list
l1=list(s)
type(l1)
# Out:
# list

# %%
#we can place a tuple inside a set cause its immutable but we cant put a list cause its mutable
s1={2,3,4,5,[3,4,5]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #we can place a tuple inside a set cause its immutable but we cant put a list cause its mutable
# ----> 2 s1={2,3,4,5,[3,4,5]}
#
# TypeError: unhashable type: 'list'

# %%
s1={2,3,4,5,(3,4,5)}
s1#indexing and slicing is not possible in set
# Out:
# {(3, 4, 5), 2, 3, 4, 5}

# %%
for i in s1:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# (3, 4, 5)

# %%
s1.add(1)#add doen't necessarily mean that the ele will be added at the end
s1
# Out:
# {(3, 4, 5), 1, 2, 3, 4, 5, 78}

# %%
s1.pop()# removes a random element
# Out:
# 1

# %%
s1.remove(3)# remove is used to remove a particular element
s1
# Out:
# {(3, 4, 5), 2, 5}

# %%
s1.add('kaist')#set can have multiple data structures
s1
# Out:
# {(3, 4, 5), 2, 5, 'kaist'}

# %%
s1.clear()#to empty the set

# %%
s1={2,3,4,5,(3,4,5)}

# %%
s1.discard(4)# it doesn't throw an error if the ele doesn't exist in a set
s1
# Out:
# {(3, 4, 5), 2, 3, 5}

# %%
s1={'hike','travel','photo'}
s2={'code','photo'}
s1|s2 # union
# Out:
# {'code', 'hike', 'photo', 'travel'}

# %%
s1 & s2 # intersection
# Out:
# {'photo'}

# %%
s1-s2 #difference
# Out:
# {'hike', 'travel'}

# %%
s1 ^ s2 #symmetric difference -ele from both a and b but not the common elements
# Out:
# {'code', 'hike', 'travel'}

# %%
# frozen sets //immutable version - cant add elements or delete them
fs=frozenset([2,3,5])#we pass them as lists
fs
# Out:
# frozenset({2, 3, 5})

# %%
type(fs)
# Out:
# frozenset

# %%
fs.add(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 fs.add(3)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
fs.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 fs.pop()
#
# AttributeError: 'frozenset' object has no attribute 'pop'
