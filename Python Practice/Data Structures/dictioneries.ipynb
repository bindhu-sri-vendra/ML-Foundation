# %%
d={}
type(d)
# Out:
# dict

# %%
d={'name':'bindhu','mail':'bindhu@gmail.com','contact':739379}
d
# Out:
# {'name': 'bindhu', 'mail': 'bindhu@gmail.com', 'contact': 739379}

# %%
d.keys()
# Out:
# dict_keys(['name', 'mail', 'contact'])

# %%
d.values()
# Out:
# dict_values(['bindhu', 'bindhu@gmail.com', 739379])

# %%
d['mail']
# Out:
# 'bindhu@gmail.com'

# %%
d['mail']='kaist@kr.com'
d
# Out:
# {'name': 'bindhu', 'mail': 'kaist@kr.com', 'contact': 739379}

# %%
d['address']='songang dorm'#to add new key value pair
d
# Out:
# {'name': 'bindhu',
#  'mail': 'kaist@kr.com',
#  'contact': 739379,
#  'address': 'songang dorm'}

# %%
#we cant have mutable data types as key values like list but we can use tuple

# %%
del d['contact']# to delete a key value pair
d
# Out:
# {'name': 'bindhu', 'mail': 'kaist@kr.com', 'address': 'songang dorm'}

# %%
del d# to delete a whole dictionary including var
#d.clear() - to empty the dictionary

# %%
d={'name':'bindhu','mail':'bindhu@gmail.com','contact':739379}
len(d)
# Out:
# 3

# %%
#to delete a particular key value pair
d.pop('contact')
d
# Out:
# {'name': 'bindhu', 'mail': 'bindhu@gmail.com'}

# %%
#fromkeys
d.fromkeys((1,2,4),('a','b','d'))
d
# Out:
# {'name': 'bindhu', 'mail': 'bindhu@gmail.com'}

# %%
#zip function
stu=['arun','barun','carun']
marks=[56,64,64]
for i in zip(stu,marks):
    print(i)
# Out:
# ('arun', 56)
# ('barun', 64)
# ('carun', 64)

# %%
stu=['arun','barun','carun']
marks=[56,64,64]
dic={}
for i,j in zip(stu,marks):
    dic[i]=j
dic
# Out:
# {'arun': 56, 'barun': 64, 'carun': 64}
