# %%
#to get ascii values we use ord()
ord('A')
# Out:
# 65

# %%
print("I'm Bindhu")
# Out:
# I'm Bindhu

# %%
'''I am Bindhu
My bf is Baka Tarajit'''
# Out:
# 'I am Bindhu\nMy bf is Baka Tarajit'

# %%
'hello ' + 'world ' +'hey'
# Out:
# 'hello world hey'

# %%
a='i got into kaist and kaist is beautiful'
a.replace('kaist','snu')
# Out:
# 'i got into snu and snu is beautiful'

# %%
b='hey, hi'
b.replace('hey','bindhu').replace('hi','vendra')
# Out:
# 'bindhu, vendra'

# %%
data='i am, bindhu, kaist student'
data.split(',')
# Out:
# ['i am', ' bindhu', ' kaist student']
