# %% [raw]
# class methods -- they are bounded to the class and they can also modify the methods and attributes of the class
# @classmethod --decorator
# instead of self we use cls

# %%
class Student:
    def __init__(self,name): #constructor
        self.name=name
    @classmethod
    def fun(cls,name):
        return cls(name)

# %%
a=Student.fun('bindhu')
a.name
# Out:
# 'bindhu'

# %%
#how class method is overloading the init method
class Student:
    def __init__(self,name): #constructor
        self.name=name
    @classmethod
    def fun(cls,name1):
        return cls(name1)
