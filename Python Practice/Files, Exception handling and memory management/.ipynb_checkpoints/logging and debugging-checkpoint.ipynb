# %% [raw]
# debugging >> the process of identifying and fixing bugs in our code
# debugging involves breaking of the code(checkpoint),executing the code and inspecting the variables using the print statement

# %%
def fun(a,b):
    return a/b
for i in range(-10,10):
    fun(i,i+1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2     return a/b
#       3 for i in range(-10,10):
# ----> 4     fun(i,i+1)
#
# Cell In[1], line 2, in fun(a, b)
#       1 def fun(a,b):
# ----> 2     return a/b
#
# ZeroDivisionError: division by zero

# %% [raw]
# In the above piece of code we are calling function many times and somewhere the code is throwing an error so we need to debug it

# %%
#process of debugging >> use print to check where the error might be occuring
def fun(a,b):
    print(a,b)
    return a/b
for i in range(-10,10):
    fun(i,i+1)
# Out:
# -10 -9
# -9 -8
# -8 -7
# -7 -6
# -6 -5
# -5 -4
# -4 -3
# -3 -2
# -2 -1
# -1 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 6
#       4     return a/b
#       5 for i in range(-10,10):
# ----> 6     fun(i,i+1)
#
# Cell In[2], line 4, in fun(a, b)
#       2 def fun(a,b):
#       3     print(a,b)
# ----> 4     return a/b
#
# ZeroDivisionError: division by zero

# %%
#from the above code we can say that when the parameter b encounters 0 we get zero division error so we place a checkpoint there
def fun(a,b):
    if b==0:
        print('zero div error')
        return
    print (a/b)
    return
for i in range(-10,10):
    fun(i,i+1)
# Out:
# 1.1111111111111112
# 1.125
# 1.1428571428571428
# 1.1666666666666667
# 1.2
# 1.25
# 1.3333333333333333
# 1.5
# 2.0
# zero div error
# 0.0
# 0.5
# 0.6666666666666666
# 0.75
# 0.8
# 0.8333333333333334
# 0.8571428571428571
# 0.875
# 0.8888888888888888
# 0.9

# %% [raw]
# In python print is not a good way to debug cause they will get lost in terminal/console
# print is good for short scripts not complex ones
# so we use the concept of logging

# %% [raw]
# Logging>> records the state and flow of the program
# It shows how the code behaves over time
#
# Analogy >> if we write a diary since childhood and if we read that diary after 10 20 years it will show our thought process from our childhood

# %% [raw]
# logging helps to log different type of messages which help us to categorize based on sevearity

# %%
import logging as lg

# %%
lg.basicConfig(filename='test.log',level=lg.INFO)

# %%
lg.info('this is normal info about the software')

# %%
lg.warning('there can be empty list here')

# %%
lg.debug('the length of the list is')

# %%
lg.error('some error has happened')

# %%
lg.critical('the software stopped running')

# %%
lg.shutdown()

# %% [raw]
# DEBUG >> This is the lowest level of logging. It is used to give detailed info of any variable or message while doing debugging
# INFO >> This is used to convey the code is working as expected
#   | Ex: Data Analysis is complete
# WARNING >> It is used basically to say there can be a potential issue in the code
# Error >> some serious problem with the code
# critical >> Very serious issue / termination of code or program
#
# The logging will be done in the same order as above
# in basicConfig level if we say level = debug log priority starts from that level info and warning cant be used
