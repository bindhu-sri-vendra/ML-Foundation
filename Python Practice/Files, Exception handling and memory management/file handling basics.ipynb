# %% [raw]
# r >> read mode
# w >> write mode
# a >> append mode
# r+ >> both read and write mode

# %% [raw]
# #if there is no file and we are trying to open that file in a read mode it will throw an error
# #to know more about the open function keep the cursor inside the braces and then hit shift+tab
# open('file.txt','r')

# %%
file = open('file.txt','w')#if the file is not there then write mode creates a file and then reads it

# %%
file.write('this is my first line in my first created file in python')# the no below is no of bytes aka no of characters
# Out:
# 56

# %%
#at this point we can't see anything we have written and to view we need to close the file
file.close()

# %%
file=open('file.txt','r')

# %%
file.closed #to know our file is open or closed
# Out:
# False

# %%
file.close()

# %%
file.closed
# Out:
# True

# %%
file.name#to know the file name
# Out:
# 'file.txt'

# %%
file.mode # to know the mode that the file has been last opened
# Out:
# 'r'

# %%
file = open('file.txt','w')# if we do this to write the w mode deletes all the prev notes and opens a fresh text file

# %%
file.close()

# %%
file = open('file.txt','w')
file.write('this is my first line\n')
file.write('this is my second line\n')
file.write('this is my third line\n')
file.write('this is my fourth line\n')
file.write('this is my fifth line\n')
file.close()

# %%
#if we open our file in w mode then it will erase all prev notes so inorder to add new content tothe file we open in append mode
file=open('file.txt','a')
file.write('this is my sixth line\n')
file.close()

# %%
#to read the content in the file we can use loop and also file need to be open in read mode
file=open('file.txt','r')
for i in file:
    print(i)
# Out:
# this is my first line
#
# this is my second line
#
# this is my third line
#
# this is my fourth line
#
# this is my fifth line
#
# this is my sixth line

# %%
file.read()#it doen't print anything bcz the cursor is at the last line

# %%
file.tell()# it tells the current position of the cursor
# Out:
# 140

# %%
file.seek(0) # to get the cursor to a particular positon
# Out:
# 0

# %%
file.tell()
# Out:
# 0

# %%
file.read()
# Out:
# 'this is my first line\nthis is my second line\nthis is my third line\nthis is my fourth line\nthis is my fifth line\nthis is my sixth line\n'

# %%
file.close()

# %%
file =open('file.txt','r')
file.readline() #it only reads the first line
# Out:
# 'this is my first line\n'

# %%
file.close()

# %%
file =open('file.txt','r')
file.readlines() #it reads all the lines and the lines will be the elements of the list
# Out:
# ['this is my first line\n',
#  'this is my second line\n',
#  'this is my third line\n',
#  'this is my fourth line\n',
#  'this is my fifth line\n',
#  'this is my sixth line\n']

# %%
file.close()

# %%
#present working directory
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os #its important and we use it to interact with the operating system
os.getcwd()
# Out:
# 'C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management'

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 7C24-C980
#
#  Directory of C:\Users\Bindhu_alia\Data Science\Python Practice\Files, Exception handling and memory management
#
# 05-09-2025  11:40    <DIR>          .
# 03-09-2025  16:38    <DIR>          ..
# 05-09-2025  11:12    <DIR>          .ipynb_checkpoints
# 05-09-2025  11:40            11,312 file handling basics.ipynb
# 05-09-2025  11:26               140 file.txt
#                2 File(s)         11,452 bytes
#                3 Dir(s)  86,843,596,800 bytes free

# %%
#to get the size of the file
os.path.getsize('file.txt')
# Out:
# 140

# %%
#to make a directory(folder)
os.mkdir('test')

# %%
#to make a directory inside a directory
os.mkdir('test/test1')

# %% [raw]
# Inorder to make the child directory the parent directory should exist first

# %%
#if we wanna create a multiple nested directories 
os.makedirs('1/2/3/4')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[51], line 2
#       1 #if we wanna create a multiple nested directories
# ----> 2 os.makedirs('1/2/3/4')
#
# File <frozen os>:228, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: '1/2/3/4'

# %%
os.listdir()# to get the list of all directories
# Out:
# ['.ipynb_checkpoints', '1', 'file handling basics.ipynb', 'file.txt', 'test']

# %%
os.rmdir('1')# to remove the directory only works for a single directory without any directory inside
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 os.rmdir('1')# to remove the directory only works for a single directory without any directory inside
#
# OSError: [WinError 145] The directory is not empty: '1'

# %%
import shutil
shutil.rmtree('test') #to remove multiple directories at once

# %%
shutil.rmtree('1')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management'

# %%
os.makedirs('test/test1')

# %%
f=open('C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\test\\test1\\file.txt','w')

# %%
# to copy a file from one location to other location 
#shutil.copy(source,destination) >> syntax
shutil.copy('C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\test\\test1\\ff.txt','C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management')
# Out:
# 'C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\ff.txt'

# %%
os.mkdir('file_test')

# %%
#to move the file from one location to another location
shutil.move('C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\file.txt','C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\file_test')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\file.txt' -> 'C:\\Users\\Bindhu_alia\\Data Science\\Python Practice\\Files, Exception handling and memory management\\file_test\\file.txt'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[70], line 2
#       1 #to move the file from one location to another location
# ...

# %%
# with ensures that the file is closed properly
with open('abb.txt','w') as f:
    f.write('this is my first line')
