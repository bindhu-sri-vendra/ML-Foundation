# %%
import numpy as np

# %%
arr1=np.random.randint(1,3,(3,3))
arr2=np.random.randint(1,4,(3,3))

# %%
arr1
# Out:
# array([[2, 1, 2],
#        [1, 1, 2],
#        [1, 2, 2]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 1, 2],
#        [3, 3, 1],
#        [2, 2, 3]], dtype=int32)

# %%
#flatten an array >> gives one dimensional array as output
arr1.flatten()
# Out:
# array([2, 1, 2, 1, 1, 2, 1, 2, 2], dtype=int32)

# %%
arr1
# Out:
# array([[2, 1, 2],
#        [1, 1, 2],
#        [1, 2, 2]], dtype=int32)

# %%
arr=np.array([1,2,3,4])
#to expand the dimension of the array 
np.expand_dims(arr,axis=0) #axis 0 means row wise(x-axis) and 1 means column wise (y-axis)
# Out:
# array([[1, 2, 3, 4]])

# %%
#to reduce the dimension
np.squeeze(arr)
# Out:
# array([1, 2, 3, 4])

# %%
arr2
# Out:
# array([[1, 1, 2],
#        [3, 3, 1],
#        [2, 2, 3]], dtype=int32)

# %%
np.repeat(arr2, 3 ,axis=0)
# Out:
# array([[1, 1, 2],
#        [1, 1, 2],
#        [1, 1, 2],
#        [3, 3, 1],
#        [3, 3, 1],
#        [3, 3, 1],
#        [2, 2, 3],
#        [2, 2, 3],
#        [2, 2, 3]], dtype=int32)

# %%
arr2
# Out:
# array([[1, 1, 2],
#        [3, 3, 1],
#        [2, 2, 3]], dtype=int32)

# %%
np.roll(arr2,-1) #first element became last element and every other element has moved forward we can use -2 -3 -4 anything there based on our need
# Out:
# array([[1, 2, 3],
#        [3, 1, 2],
#        [2, 3, 1]], dtype=int32)

# %%
~arr2 # negative of each element with one up
# Out:
# array([[-2, -2, -3],
#        [-4, -4, -2],
#        [-3, -3, -4]], dtype=int32)

# %%
#string array 
d=np.array(['bindhu','got','into','kaist'])
d
# Out:
# array(['bindhu', 'got', 'into', 'kaist'], dtype='<U6')

# %%
np.char.upper(d)# to convert all strings into uppercase
# Out:
# array(['BINDHU', 'GOT', 'INTO', 'KAIST'], dtype='<U6')

# %%
arr1
# Out:
# array([[2, 1, 2],
#        [1, 1, 2],
#        [1, 2, 2]], dtype=int32)

# %%
np.sin(arr1)
# Out:
# array([[0.90929743, 0.84147098, 0.90929743],
#        [0.84147098, 0.84147098, 0.90929743],
#        [0.84147098, 0.90929743, 0.90929743]])

# %%
np.tan(arr1) #only has sin cos and tan
# Out:
# array([[-2.18503986,  1.55740772, -2.18503986],
#        [ 1.55740772,  1.55740772, -2.18503986],
#        [ 1.55740772, -2.18503986, -2.18503986]])

# %%
np.log10(arr1)
# Out:
# array([[0.30103, 0.     , 0.30103],
#        [0.     , 0.     , 0.30103],
#        [0.     , 0.30103, 0.30103]])

# %%
np.exp(arr1)
# Out:
# array([[7.3890561 , 2.71828183, 7.3890561 ],
#        [2.71828183, 2.71828183, 7.3890561 ],
#        [2.71828183, 7.3890561 , 7.3890561 ]])

# %%
np.power(arr1,3) # goes index wise arr[1]^3 does the same thing for all elements
# Out:
# array([[8, 1, 8],
#        [1, 1, 8],
#        [1, 8, 8]], dtype=int32)

# %%
#to get max value from the array
np.max(arr1)
# Out:
# np.int32(2)

# %%
np.min(arr1)
# Out:
# np.int32(1)

# %%
np.mean(arr1)
# Out:
# np.float64(1.5555555555555556)

# %%
np.std(arr1)
# Out:
# np.float64(0.4969039949999533)

# %%
np.var(arr1)
# Out:
# np.float64(0.2469135802469136)

# %%
np.subtract(arr1,arr2) #same result as arr1 - arr2
# Out:
# array([[ 1,  0,  0],
#        [-2, -2,  1],
#        [-1,  0, -1]], dtype=int32)

# %%
np.multiply(arr1,arr2)
# Out:
# array([[2, 1, 4],
#        [3, 3, 2],
#        [2, 4, 6]], dtype=int32)

# %%
np.mod(arr1,arr2) # returns element wise remainder
# Out:
# array([[0, 0, 0],
#        [1, 1, 0],
#        [1, 0, 2]], dtype=int32)

# %%
np.sort(arr1) # returns sorted elements in ascending order in row wise sort
# Out:
# array([[1, 2, 2],
#        [1, 1, 2],
#        [1, 2, 2]], dtype=int32)

# %%
arr1
# Out:
# array([[2, 1, 2],
#        [1, 1, 2],
#        [1, 2, 2]], dtype=int32)

# %%
np.count_nonzero(arr1)
# Out:
# np.int64(9)

# %%
np.where(arr1>0)
# Out:
# (array([0, 0, 0, 1, 1, 1, 2, 2, 2]), array([0, 1, 2, 0, 1, 2, 0, 1, 2]))

# %%
import numpy.matlib as nm

# %%
nm.zeros(5,dtype=int)
# Out:
# matrix([[0, 0, 0, 0, 0]])

# %%
np.linalg.inv(arr1) # inverse of the matrix
# Out:
# array([[ 1.00000000e+00, -1.00000000e+00, -1.11022302e-16],
#        [ 0.00000000e+00, -1.00000000e+00,  1.00000000e+00],
#        [-5.00000000e-01,  1.50000000e+00, -5.00000000e-01]])
