# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.0 MB 2.3 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 2.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 3.3 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/11.0 MB 3.7 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/11.0 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 4.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 5.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('services.csv')

# %%
#by default pandas understand the first row as column names to avoid that 
pd.read_csv('services.csv',header=None)
# Out:
#     0            1           2                         3   \
# 0   id  location_id  program_id         accepted_payments
# 1    1            1         NaN                       NaN
# 2    2            2         NaN                       NaN
# 3    3            3         NaN                       NaN
# 4    4            4         NaN                       NaN
# 5    5            5         NaN                       NaN
# 6    6            6         NaN                       NaN
# 7    7            7         NaN                       NaN
# 8    8            8         NaN                       NaN
# 9    9            9         NaN                       NaN
# 10  10           10         NaN                       NaN
# 11  11           11         NaN                       NaN
# 12  12           12         NaN                       NaN
# 13  13           13         NaN                       NaN
# 14  14           14         NaN                       NaN
# ...

# %%
#if we wanna skip rows 
pd.read_csv('services.csv',skiprows=2,header=None)# it skips the first two rows
# Out:
#     0   1   2                         3                      4   \
# 0    2   2 NaN                       NaN                    NaN
# 1    3   3 NaN                       NaN                    NaN
# 2    4   4 NaN                       NaN                    NaN
# 3    5   5 NaN                       NaN                    NaN
# 4    6   6 NaN                       NaN                    NaN
# 5    7   7 NaN                       NaN                    NaN
# 6    8   8 NaN                       NaN                    NaN
# 7    9   9 NaN                       NaN                    NaN
# 8   10  10 NaN                       NaN                    NaN
# 9   11  11 NaN                       NaN                    NaN
# 10  12  12 NaN                       NaN                    NaN
# 11  13  13 NaN                       NaN                    NaN
# 12  14  14 NaN                       NaN                    NaN
# 13  15  15 NaN                       NaN                    NaN
# ...

# %%
# if we wanna read particular columns 
pd.read_csv('services.csv',usecols=['program_id','application_process','eligibility'])
# Out:
#     program_id                                application_process  \
# 0          NaN                         Walk in or apply by phone.
# 1          NaN                 Apply by phone for an appointment.
# 2          NaN        Phone for information (403-4300 Ext. 4322).
# 3          NaN                                    Apply by phone.
# 4          NaN                             Phone for information.
# 5          NaN  Walk in or apply by phone for membership appli...
# 6          NaN  Apply by phone or be referred by a doctor, soc...
# 7          NaN                                    Apply by phone.
# 8          NaN  Walk in. Proof of residency in California requ...
# 9          NaN  Walk in. Proof of California residency to rece...
# 10         NaN  Walk in. Proof of California residency require...
# 11         NaN  Walk in or apply by phone, email or webpage re...
# 12         NaN  Walk in. Proof of California residency require...
# ...

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
#if we want to access a particular column
df.application_process
#df['application_process'] >>alternate way to access columns
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
type(df['application_process'])# column is a series in a dataframe and multile series form a data frame
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#we can convert a list into series
l=[1,2,3,4]
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#by default the indexes are integers but we can also have custom integers
l=[1,2,3,4]
a=pd.Series(l,index=['bindhu','got','into','kaist'])

# %%
a
# Out:
# bindhu    1
# got       2
# into      3
# kaist     4
# dtype: int64

# %%
a.index
# Out:
# Index(['bindhu', 'got', 'into', 'kaist'], dtype='object')

# %%
#we can just reset the indexes to prev ones as well
a.reset_index(drop=True)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#to see the first 5 rows of the data 
df.head() # we can give any number in head to view that many rows >> head(8) gives first 8 rows
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
df.tail() #similar to head but gives the last 5 rows by default we can mention any number in tail to view that many rows
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#to see how many rows and cols are there in a data frame
df.shape
# Out:
# (23, 22)

# %%
#to get the columns info 
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#to view random data 
df.sample(3) # by default it gives one random row but we can mention how many random rows we need
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 20  21           21         NaN               NaN            NaN
# 6    7            7         NaN               NaN            NaN
# 22  23           22         NaN               NaN            NaN
#
#                                   application_process  \
# 20                    By phone during business hours.
# 6   Apply by phone or be referred by a doctor, soc...
# 22                  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 6   Older adults who have memory or sensory loss, ...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description     eligibility email  \
# 20                                just a test service             NaN   NaN
# 6   Rosener House is a day center for older adults...  Age 18 or over   NaN
# ...

# %% [raw]
# The important part of data analysis is to know our data fully
# 1. check rows and columns
# 2. check head()
# 3. check tail()
# 4. check sample()
# 5. Check data type of the columns

# %%
# to get the data types of all the columns 
df.info() # here object data type means string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              17 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
# ...

# %%
#alternate way to check the datatypes of the columns 
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
#we can convert our column into a list
list(df['languages'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'Spanish',
#  nan]

# %%
a=[1,2,3,4]
a=pd.Series(a)

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#to convert series into a dataframe
a=pd.DataFrame(a)

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
#to add a new column
a['new col']=6 # inplace of 6 we can use any number and any string
a
# Out:
#    0  new_col  new col
# 0  1        6        6
# 1  2        6        6
# 2  3        6        6
# 3  4        6        6

# %%
a['new col']# it is the best way to acees a col cause if we use a.new col it throws an error because of the space
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# Name: new col, dtype: int64

# %%
#to change column names
a.columns=['col1','col2','col3']

# %%
a
# Out:
#    col1  col2  col3
# 0     1     6     6
# 1     2     6     6
# 2     3     6     6
# 3     4     6     6

# %%
a.reset_index(drop=True)
# Out:
#    col1  col2  col3
# 0     1     6     6
# 1     2     6     6
# 2     3     6     6
# 3     4     6     6

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df[['application_process', 'audience']]#if we wanna access two columns at once make it a dataframe cause series is oned and if we access twocol at once it becomes 2d
#we can pass any no of columns in the above frame it will work as a dataframw with no issues
# Out:
#                                   application_process  \
# 0                          Walk in or apply by phone.
# 1                  Apply by phone for an appointment.
# 2         Phone for information (403-4300 Ext. 4322).
# 3                                     Apply by phone.
# 4                              Phone for information.
# 5   Walk in or apply by phone for membership appli...
# 6   Apply by phone or be referred by a doctor, soc...
# 7                                     Apply by phone.
# 8   Walk in. Proof of residency in California requ...
# 9   Walk in. Proof of California residency to rece...
# 10  Walk in. Proof of California residency require...
# 11  Walk in or apply by phone, email or webpage re...
# 12  Walk in. Proof of California residency require...
# 13  Call for appointment. Referral from human serv...
# 14          Walk in or through other agency referral.
# 15  Walk in. Written application, identification r...
# ...

# %%
#to read an excel we need to have both pandas and openpyxl
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#to read an excel file
ex=pd.read_excel('LUSID Excel - Setting up your market data.xlsx')

# %%
ex
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...
