# %% [raw]
# data interpolation >> estimating unknown values from known values
# [so we have 2 known data points .-----. ,- is the synthetic points we generate in between those known data points and that is interpolation  ]
#
# it is 3 types
# 1. linear interpolation
# 2. cubic interpolation
# 3. polynomial interpolation

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=np.array([1,2,3,4,5])
y=np.array([1,3,5,7,9])

# %%
plt.scatter(x,y)

# %%
#linear interpolation
x_new=np.linspace(1,5,10)
y_interp=np.interp(x_new,x,y)

# %%
y_interp
# Out:
# array([1.        , 1.88888889, 2.77777778, 3.66666667, 4.55555556,
#        5.44444444, 6.33333333, 7.22222222, 8.11111111, 9.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
#cubic interpolation
x=np.array([1,2,3,4,5])
y=np.array([1,8,27,64,125])
plt.scatter(x,y)

# %%
from scipy.interpolate import interp1d

# %%
f=interp1d(x,y,kind='cubic')

# %%
f

# %%
x_new=np.linspace(1,5,10)
y_interp=f(x_new)

# %%
y_interp
# Out:
# array([  1.        ,   3.01371742,   6.739369  ,  12.7037037 ,
#         21.43347051,  33.45541838,  49.2962963 ,  69.48285322,
#         94.54183813, 125.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
#polynomial interpretation
x=np.array([1,2,3,4,5])
y=np.array([1,3,5,9,32])
plt.scatter(x,y)

# %%
p=np.polyfit(x,y,2)

# %%
x_new=np.linspace(x,y,2)
y_interp =np.polyval(p,x_new)

# %%
plt.scatter(x_new,y_interp)
