# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('student_mental_health.csv')
df2 = pd.read_csv('student_lifestyle_dataset.csv')
df3 = pd.read_csv('survey.csv')

# %%
df3.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %%
target = df2.columns[5]

df2.corr(numeric_only=True)[target].sort_values(ascending=False)
# Out:
# Physical_Activity_Hours_Per_Day    1.000000
# Student_ID                         0.004273
# GPA                               -0.341152
# Extracurricular_Hours_Per_Day     -0.369989
# Social_Hours_Per_Day              -0.417142
# Sleep_Hours_Per_Day               -0.470302
# Study_Hours_Per_Day               -0.488113
# Name: Physical_Activity_Hours_Per_Day, dtype: float64

# %%
df2.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...
